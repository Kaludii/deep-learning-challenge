# %% [markdown]
# ## Preprocessing

# %%
# Import our dependencies
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
import pandas as pd
import tensorflow as tf

#  Import and read the charity_data.csv.
import pandas as pd 
application_df = pd.read_csv("./Resources/charity_data.csv")
application_df.head()
# Out:
#         EIN                                      NAME APPLICATION_TYPE  \
# 0  10520599              BLUE KNIGHTS MOTORCYCLE CLUB              T10
# 1  10531628    AMERICAN CHESAPEAKE CLUB CHARITABLE TR               T3
# 2  10547893        ST CLOUD PROFESSIONAL FIREFIGHTERS               T5
# 3  10553066            SOUTHSIDE ATHLETIC ASSOCIATION               T3
# 4  10556103  GENETIC RESEARCH INSTITUTE OF THE DESERT               T3
#
#         AFFILIATION CLASSIFICATION      USE_CASE  ORGANIZATION  STATUS  \
# 0       Independent          C1000    ProductDev   Association       1
# 1       Independent          C2000  Preservation  Co-operative       1
# 2  CompanySponsored          C3000    ProductDev   Association       1
# 3  CompanySponsored          C2000  Preservation         Trust       1
# 4       Independent          C1000     Heathcare         Trust       1
#
#       INCOME_AMT SPECIAL_CONSIDERATIONS  ASK_AMT  IS_SUCCESSFUL
# 0              0                      N     5000              1
# 1         1-9999                      N   108590              1
# 2              0                      N     5000              0
# 3    10000-24999                      N     6692              1
# 4  100000-499999                      N   142590              1

# %%
# Drop the non-beneficial ID columns, 'EIN' and 'NAME'
application_df = application_df.drop(['EIN', 'NAME', 'STATUS'], axis=1)
application_df.head()
# Out:
#   APPLICATION_TYPE       AFFILIATION CLASSIFICATION      USE_CASE  \
# 0              T10       Independent          C1000    ProductDev
# 1               T3       Independent          C2000  Preservation
# 2               T5  CompanySponsored          C3000    ProductDev
# 3               T3  CompanySponsored          C2000  Preservation
# 4               T3       Independent          C1000     Heathcare
#
#    ORGANIZATION     INCOME_AMT SPECIAL_CONSIDERATIONS  ASK_AMT  IS_SUCCESSFUL
# 0   Association              0                      N     5000              1
# 1  Co-operative         1-9999                      N   108590              1
# 2   Association              0                      N     5000              0
# 3         Trust    10000-24999                      N     6692              1
# 4         Trust  100000-499999                      N   142590              1

# %%
# Determine the number of unique values in each column.
unique_values = application_df.nunique()
print("Number of unique values in each column: \n", unique_values)
# Out:
# Number of unique values in each column:
#  APPLICATION_TYPE            17
# AFFILIATION                  6
# CLASSIFICATION              71
# USE_CASE                     5
# ORGANIZATION                 4
# INCOME_AMT                   9
# SPECIAL_CONSIDERATIONS       2
# ASK_AMT                   8747
# IS_SUCCESSFUL                2
# dtype: int64

# %%
# Look at APPLICATION_TYPE value counts for binning
application_type_counts = application_df["APPLICATION_TYPE"].value_counts()
print("APPLICATION_TYPE value counts: \n", application_type_counts)
# Out:
# APPLICATION_TYPE value counts:
#  T3     27037
# T4      1542
# T6      1216
# T5      1173
# T19     1065
# T8       737
# T7       725
# T10      528
# T9       156
# T13       66
# T12       27
# T2        16
# T25        3
# T14        3
# T29        2
# T15        2
# T17        1
# Name: APPLICATION_TYPE, dtype: int64

# %%
# Choose a cutoff value and create a list of application types to be replaced
cutoff = 1000
application_types_to_replace = application_type_counts[application_type_counts <= cutoff].index.tolist()

# Replace in dataframe
for app in application_types_to_replace:
    application_df['APPLICATION_TYPE'] = application_df['APPLICATION_TYPE'].replace(app,"Other")

# Check to make sure binning was successful
print("APPLICATION_TYPE value counts after binning: \n", application_df['APPLICATION_TYPE'].value_counts())
# Out:
# APPLICATION_TYPE value counts after binning:
#  T3       27037
# Other     2266
# T4        1542
# T6        1216
# T5        1173
# T19       1065
# Name: APPLICATION_TYPE, dtype: int64

# %%
# Look at CLASSIFICATION value counts for binning
classification_counts = application_df["CLASSIFICATION"].value_counts()
print("CLASSIFICATION value counts: \n", classification_counts)
# Out:
# CLASSIFICATION value counts:
#  C1000    17326
# C2000     6074
# C1200     4837
# C3000     1918
# C2100     1883
#          ...
# C4120        1
# C8210        1
# C2561        1
# C4500        1
# C2150        1
# Name: CLASSIFICATION, Length: 71, dtype: int64

# %%
# Look at CLASSIFICATION value counts >1
classification_counts_above_1 = classification_counts[classification_counts > 1]
print("CLASSIFICATION value counts above 1: \n", classification_counts_above_1)
# Out:
# CLASSIFICATION value counts above 1:
#  C1000    17326
# C2000     6074
# C1200     4837
# C3000     1918
# C2100     1883
# C7000      777
# C1700      287
# C4000      194
# C5000      116
# C1270      114
# C2700      104
# C2800       95
# C7100       75
# C1300       58
# C1280       50
# C1230       36
# C1400       34
# C7200       32
# C2300       32
# C1240       30
# C8000       20
# C7120       18
# C1500       16
# C1800       15
# C6000       15
# C1250       14
# C8200       11
# C1238       10
# C1278       10
# C1235        9
# C1237        9
# C7210        7
# C2400        6
# C1720        6
# C4100        6
# C1257        5
# C1600        5
# C1260        3
# C2710        3
# C0           3
# C3200        2
# C1234        2
# C1246        2
# C1267        2
# C1256        2
# Name: CLASSIFICATION, dtype: int64

# %%
# Choose a cutoff value and create a list of classifications to be replaced
cutoff = 20
classification_counts = application_df['CLASSIFICATION'].value_counts()
classifications_to_replace = classification_counts[classification_counts <= cutoff].index.tolist()

# Replace in dataframe
for cls in classifications_to_replace:
    application_df['CLASSIFICATION'] = application_df['CLASSIFICATION'].replace(cls,"Other")
    
# Check to make sure binning was successful
application_df['CLASSIFICATION'].value_counts()
# Out:
# C1000    17326
# C2000     6074
# C1200     4837
# C3000     1918
# C2100     1883
# C7000      777
# C1700      287
# Other      227
# C4000      194
# C5000      116
# C1270      114
# C2700      104
# C2800       95
# C7100       75
# C1300       58
# C1280       50
# C1230       36
# C1400       34
# C7200       32
# C2300       32
# C1240       30
# Name: CLASSIFICATION, dtype: int64

# %%
# Convert categorical data to numeric with `pd.get_dummies`
application_df = pd.get_dummies(application_df)

# %%
# Split our preprocessed data into our features and target arrays
y = application_df["IS_SUCCESSFUL"].values
X = application_df.drop("IS_SUCCESSFUL", axis=1).values

# Split the preprocessed data into a training and testing dataset
X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=78)

# %%
# Create a StandardScaler instances
scaler = StandardScaler()

# Fit the StandardScaler
X_scaler = scaler.fit(X_train)

# Scale the data
X_train_scaled = X_scaler.transform(X_train)
X_test_scaled = X_scaler.transform(X_test)

# %% [markdown]
# ## Compile, Train and Evaluate the Model

# %%
# Define the model - deep neural net, i.e., the number of input features and hidden nodes for each layer.
number_input_features = len(X_train_scaled[0])
hidden_nodes_layer1 = 100
hidden_nodes_layer2 = 50
hidden_nodes_layer3 = 25

nn = tf.keras.models.Sequential()

# First hidden layer
nn.add(
tf.keras.layers.Dense(units=hidden_nodes_layer1, activation='relu', input_dim=number_input_features)
)

# Second hidden layer
nn.add(
tf.keras.layers.Dense(units=hidden_nodes_layer2, activation='relu')
)

# Third hidden layer
nn.add(
tf.keras.layers.Dense(units=hidden_nodes_layer3, activation='relu')
)

# Output layer
nn.add(
tf.keras.layers.Dense(units=1, activation='sigmoid')
)

# Check the structure of the model
nn.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense (Dense)               (None, 100)               5500
#
#  dense_1 (Dense)             (None, 50)                5050
#
#  dense_2 (Dense)             (None, 25)                1275
#
#  dense_3 (Dense)             (None, 1)                 26
#
# =================================================================
# Total params: 11,851
# Trainable params: 11,851
# Non-trainable params: 0
# _________________________________________________________________

# %%
# Compile the model
nn.compile(loss="mean_squared_error", optimizer="Adagrad", metrics=["accuracy"])

# %%
# Train the model
fit_model = nn.fit(X_train_scaled, y_train, epochs=300)
# Out:
# Epoch 1/300
# 804/804 [==============================] - 1s 654us/step - loss: 0.1775 - accuracy: 0.7441
# Epoch 2/300
# 804/804 [==============================] - 1s 673us/step - loss: 0.1773 - accuracy: 0.7442
# Epoch 3/300
# 804/804 [==============================] - 1s 680us/step - loss: 0.1773 - accuracy: 0.7442
# Epoch 4/300
# 804/804 [==============================] - 1s 671us/step - loss: 0.1772 - accuracy: 0.7443
# Epoch 5/300
# 804/804 [==============================] - 1s 657us/step - loss: 0.1772 - accuracy: 0.7442
# Epoch 6/300
# 804/804 [==============================] - 1s 661us/step - loss: 0.1772 - accuracy: 0.7441
# Epoch 7/300
# 804/804 [==============================] - 1s 655us/step - loss: 0.1772 - accuracy: 0.7441
# Epoch 8/300
# 804/804 [==============================] - 1s 659us/step - loss: 0.1772 - accuracy: 0.7440
# Epoch 9/300
# 804/804 [==============================] - 1s 657us/step - loss: 0.1772 - accuracy: 0.7441
# Epoch 10/300
# 804/804 [==============================] - 1s 656us/step - loss: 0.1772 - accuracy: 0.7439
# Epoch 11/300
# 804/804 [==============================] - 1s 656us/step - loss: 0.1772 - accuracy: 0.7439
# Epoch 12/300
# 804/804 [==============================] - 1s 668us/step - loss: 0.1772 - accuracy: 0.7444
# Epoch 13/300
# 804/804 [==============================] - 1s 654us/step - loss: 0.1772 - accuracy: 0.7443
# Epoch 14/300
# 804/804 [==============================] - 1s 656us/step - loss: 0.1772 - accuracy: 0.7443
# Epoch 15/300
# 804/804 [==============================] - 1s 652us/step - loss: 0.1772 - accuracy: 0.7442
# Epoch 16/300
# 804/804 [==============================] - 1s 662us/step - loss: 0.1772 - accuracy: 0.7441
# Epoch 17/300
# 804/804 [==============================] - 1s 665us/step - loss: 0.1772 - accuracy: 0.7441
# Epoch 18/300
# 804/804 [==============================] - 1s 650us/step - loss: 0.1772 - accuracy: 0.7442
# Epoch 19/300
# 804/804 [==============================] - 1s 645us/step - loss: 0.1772 - accuracy: 0.7442
# Epoch 20/300
# 804/804 [==============================] - 1s 651us/step - loss: 0.1771 - accuracy: 0.7444
# Epoch 21/300
# 804/804 [==============================] - 1s 650us/step - loss: 0.1771 - accuracy: 0.7442
# Epoch 22/300
# 804/804 [==============================] - 1s 652us/step - loss: 0.1771 - accuracy: 0.7442
# Epoch 23/300
# 804/804 [==============================] - 1s 648us/step - loss: 0.1771 - accuracy: 0.7443
# Epoch 24/300
# 804/804 [==============================] - 1s 652us/step - loss: 0.1771 - accuracy: 0.7444
# Epoch 25/300
# 804/804 [==============================] - 1s 656us/step - loss: 0.1771 - accuracy: 0.7444
# Epoch 26/300
# 804/804 [==============================] - 1s 650us/step - loss: 0.1771 - accuracy: 0.7442
# Epoch 27/300
# 804/804 [==============================] - 1s 656us/step - loss: 0.1771 - accuracy: 0.7442
# Epoch 28/300
# 804/804 [==============================] - 1s 648us/step - loss: 0.1771 - accuracy: 0.7442
# Epoch 29/300
# 804/804 [==============================] - 1s 653us/step - loss: 0.1771 - accuracy: 0.7442
# Epoch 30/300
# 804/804 [==============================] - 1s 644us/step - loss: 0.1771 - accuracy: 0.7443
# Epoch 31/300
# 804/804 [==============================] - 1s 657us/step - loss: 0.1771 - accuracy: 0.7441
# Epoch 32/300
# 804/804 [==============================] - 1s 645us/step - loss: 0.1771 - accuracy: 0.7443
# Epoch 33/300
# 804/804 [==============================] - 1s 653us/step - loss: 0.1771 - accuracy: 0.7442
# Epoch 34/300
# 804/804 [==============================] - 1s 647us/step - loss: 0.1771 - accuracy: 0.7443
# Epoch 35/300
# 804/804 [==============================] - 1s 650us/step - loss: 0.1771 - accuracy: 0.7446
# Epoch 36/300
# 804/804 [==============================] - 1s 652us/step - loss: 0.1771 - accuracy: 0.7444
# Epoch 37/300
# 804/804 [==============================] - 1s 645us/step - loss: 0.1771 - accuracy: 0.7442
# Epoch 38/300
# 804/804 [==============================] - 1s 641us/step - loss: 0.1771 - accuracy: 0.7445
# Epoch 39/300
# 804/804 [==============================] - 1s 646us/step - loss: 0.1771 - accuracy: 0.7444
# Epoch 40/300
# 804/804 [==============================] - 1s 643us/step - loss: 0.1771 - accuracy: 0.7444
# Epoch 41/300
# 804/804 [==============================] - 1s 651us/step - loss: 0.1771 - accuracy: 0.7444
# Epoch 42/300
# 804/804 [==============================] - 1s 642us/step - loss: 0.1771 - accuracy: 0.7446
# Epoch 43/300
# 804/804 [==============================] - 1s 646us/step - loss: 0.1771 - accuracy: 0.7442
# Epoch 44/300
# 804/804 [==============================] - 1s 642us/step - loss: 0.1771 - accuracy: 0.7444
# Epoch 45/300
# 804/804 [==============================] - 1s 642us/step - loss: 0.1771 - accuracy: 0.7444
# Epoch 46/300
# 804/804 [==============================] - 1s 640us/step - loss: 0.1771 - accuracy: 0.7442
# Epoch 47/300
# 804/804 [==============================] - 1s 652us/step - loss: 0.1771 - accuracy: 0.7445
# Epoch 48/300
# 804/804 [==============================] - 1s 640us/step - loss: 0.1771 - accuracy: 0.7443
# Epoch 49/300
# 804/804 [==============================] - 1s 647us/step - loss: 0.1771 - accuracy: 0.7442
# Epoch 50/300
# 804/804 [==============================] - 1s 643us/step - loss: 0.1771 - accuracy: 0.7444
# Epoch 51/300
# 804/804 [==============================] - 1s 649us/step - loss: 0.1771 - accuracy: 0.7445
# Epoch 52/300
# 804/804 [==============================] - 1s 652us/step - loss: 0.1771 - accuracy: 0.7443
# Epoch 53/300
# 804/804 [==============================] - 1s 647us/step - loss: 0.1771 - accuracy: 0.7443
# Epoch 54/300
# 804/804 [==============================] - 1s 647us/step - loss: 0.1771 - accuracy: 0.7444
# Epoch 55/300
# 804/804 [==============================] - 1s 679us/step - loss: 0.1771 - accuracy: 0.7444
# Epoch 56/300
# 804/804 [==============================] - 1s 650us/step - loss: 0.1771 - accuracy: 0.7445
# Epoch 57/300
# 804/804 [==============================] - 1s 660us/step - loss: 0.1771 - accuracy: 0.7444
# Epoch 58/300
# 804/804 [==============================] - 1s 645us/step - loss: 0.1771 - accuracy: 0.7443
# Epoch 59/300
# 804/804 [==============================] - 1s 650us/step - loss: 0.1771 - accuracy: 0.7444
# Epoch 60/300
# 804/804 [==============================] - 1s 648us/step - loss: 0.1771 - accuracy: 0.7445
# Epoch 61/300
# 804/804 [==============================] - 1s 657us/step - loss: 0.1771 - accuracy: 0.7445
# Epoch 62/300
# 804/804 [==============================] - 1s 647us/step - loss: 0.1771 - accuracy: 0.7442
# Epoch 63/300
# 804/804 [==============================] - 1s 653us/step - loss: 0.1771 - accuracy: 0.7444
# Epoch 64/300
# 804/804 [==============================] - 1s 644us/step - loss: 0.1771 - accuracy: 0.7444
# Epoch 65/300
# 804/804 [==============================] - 1s 645us/step - loss: 0.1771 - accuracy: 0.7445
# Epoch 66/300
# 804/804 [==============================] - 1s 653us/step - loss: 0.1771 - accuracy: 0.7446
# Epoch 67/300
# 804/804 [==============================] - 1s 648us/step - loss: 0.1771 - accuracy: 0.7444
# Epoch 68/300
# 804/804 [==============================] - 1s 646us/step - loss: 0.1771 - accuracy: 0.7445
# Epoch 69/300
# 804/804 [==============================] - 1s 653us/step - loss: 0.1771 - accuracy: 0.7445
# Epoch 70/300
# 804/804 [==============================] - 1s 652us/step - loss: 0.1771 - accuracy: 0.7444
# Epoch 71/300
# 804/804 [==============================] - 1s 672us/step - loss: 0.1771 - accuracy: 0.7444
# Epoch 72/300
# 804/804 [==============================] - 1s 643us/step - loss: 0.1771 - accuracy: 0.7445
# Epoch 73/300
# 804/804 [==============================] - 1s 649us/step - loss: 0.1771 - accuracy: 0.7445
# Epoch 74/300
# 804/804 [==============================] - 1s 647us/step - loss: 0.1771 - accuracy: 0.7446
# Epoch 75/300
# 804/804 [==============================] - 1s 662us/step - loss: 0.1771 - accuracy: 0.7445
# Epoch 76/300
# 804/804 [==============================] - 1s 647us/step - loss: 0.1771 - accuracy: 0.7447
# Epoch 77/300
# 804/804 [==============================] - 1s 651us/step - loss: 0.1771 - accuracy: 0.7445
# Epoch 78/300
# 804/804 [==============================] - 1s 645us/step - loss: 0.1771 - accuracy: 0.7445
# Epoch 79/300
# 804/804 [==============================] - 1s 653us/step - loss: 0.1771 - accuracy: 0.7445
# Epoch 80/300
# 804/804 [==============================] - 1s 651us/step - loss: 0.1771 - accuracy: 0.7445
# Epoch 81/300
# 804/804 [==============================] - 1s 647us/step - loss: 0.1771 - accuracy: 0.7444
# Epoch 82/300
# 804/804 [==============================] - 1s 645us/step - loss: 0.1771 - accuracy: 0.7445
# Epoch 83/300
# 804/804 [==============================] - 1s 652us/step - loss: 0.1771 - accuracy: 0.7446
# Epoch 84/300
# 804/804 [==============================] - 1s 656us/step - loss: 0.1771 - accuracy: 0.7445
# Epoch 85/300
# 804/804 [==============================] - 1s 646us/step - loss: 0.1771 - accuracy: 0.7444
# Epoch 86/300
# 804/804 [==============================] - 1s 652us/step - loss: 0.1771 - accuracy: 0.7446
# Epoch 87/300
# 804/804 [==============================] - 1s 646us/step - loss: 0.1771 - accuracy: 0.7446
# Epoch 88/300
# 804/804 [==============================] - 1s 644us/step - loss: 0.1771 - accuracy: 0.7446
# Epoch 89/300
# 804/804 [==============================] - 1s 653us/step - loss: 0.1771 - accuracy: 0.7445
# Epoch 90/300
# 804/804 [==============================] - 1s 643us/step - loss: 0.1771 - accuracy: 0.7444
# Epoch 91/300
# 804/804 [==============================] - 1s 642us/step - loss: 0.1771 - accuracy: 0.7444
# Epoch 92/300
# 804/804 [==============================] - 1s 654us/step - loss: 0.1771 - accuracy: 0.7446
# Epoch 93/300
# 804/804 [==============================] - 1s 653us/step - loss: 0.1771 - accuracy: 0.7445
# Epoch 94/300
# 804/804 [==============================] - 1s 652us/step - loss: 0.1771 - accuracy: 0.7444
# Epoch 95/300
# 804/804 [==============================] - 1s 647us/step - loss: 0.1771 - accuracy: 0.7445
# Epoch 96/300
# 804/804 [==============================] - 1s 648us/step - loss: 0.1771 - accuracy: 0.7446
# Epoch 97/300
# 804/804 [==============================] - 1s 640us/step - loss: 0.1771 - accuracy: 0.7445
# Epoch 98/300
# 804/804 [==============================] - 1s 657us/step - loss: 0.1771 - accuracy: 0.7445
# Epoch 99/300
# 804/804 [==============================] - 1s 642us/step - loss: 0.1771 - accuracy: 0.7445
# Epoch 100/300
# 804/804 [==============================] - 1s 653us/step - loss: 0.1771 - accuracy: 0.7446
# Epoch 101/300
# 804/804 [==============================] - 1s 648us/step - loss: 0.1771 - accuracy: 0.7446
# Epoch 102/300
# 804/804 [==============================] - 1s 655us/step - loss: 0.1771 - accuracy: 0.7445
# Epoch 103/300
# 804/804 [==============================] - 1s 646us/step - loss: 0.1771 - accuracy: 0.7445
# Epoch 104/300
# 804/804 [==============================] - 1s 654us/step - loss: 0.1771 - accuracy: 0.7444
# Epoch 105/300
# 804/804 [==============================] - 1s 646us/step - loss: 0.1771 - accuracy: 0.7445
# Epoch 106/300
# 804/804 [==============================] - 1s 651us/step - loss: 0.1771 - accuracy: 0.7445
# Epoch 107/300
# 804/804 [==============================] - 1s 653us/step - loss: 0.1771 - accuracy: 0.7445
# Epoch 108/300
# 804/804 [==============================] - 1s 648us/step - loss: 0.1771 - accuracy: 0.7444
# Epoch 109/300
# 804/804 [==============================] - 1s 647us/step - loss: 0.1771 - accuracy: 0.7446
# Epoch 110/300
# 804/804 [==============================] - 1s 660us/step - loss: 0.1771 - accuracy: 0.7446
# Epoch 111/300
# 804/804 [==============================] - 1s 658us/step - loss: 0.1771 - accuracy: 0.7445
# Epoch 112/300
# 804/804 [==============================] - 1s 647us/step - loss: 0.1771 - accuracy: 0.7444
# Epoch 113/300
# 804/804 [==============================] - 1s 646us/step - loss: 0.1771 - accuracy: 0.7446
# Epoch 114/300
# 804/804 [==============================] - 1s 658us/step - loss: 0.1771 - accuracy: 0.7445
# Epoch 115/300
# 804/804 [==============================] - 1s 656us/step - loss: 0.1771 - accuracy: 0.7444
# Epoch 116/300
# 804/804 [==============================] - 1s 659us/step - loss: 0.1771 - accuracy: 0.7446
# Epoch 117/300
# 804/804 [==============================] - 1s 648us/step - loss: 0.1771 - accuracy: 0.7445
# Epoch 118/300
# 804/804 [==============================] - 1s 651us/step - loss: 0.1771 - accuracy: 0.7445
# Epoch 119/300
# 804/804 [==============================] - 1s 650us/step - loss: 0.1771 - accuracy: 0.7445
# Epoch 120/300
# 804/804 [==============================] - 1s 656us/step - loss: 0.1771 - accuracy: 0.7446
# Epoch 121/300
# 804/804 [==============================] - 1s 653us/step - loss: 0.1771 - accuracy: 0.7446
# Epoch 122/300
# 804/804 [==============================] - 1s 650us/step - loss: 0.1771 - accuracy: 0.7446
# Epoch 123/300
# 804/804 [==============================] - 1s 645us/step - loss: 0.1771 - accuracy: 0.7446
# Epoch 124/300
# 804/804 [==============================] - 1s 653us/step - loss: 0.1771 - accuracy: 0.7445
# Epoch 125/300
# 804/804 [==============================] - 1s 661us/step - loss: 0.1771 - accuracy: 0.7445
# Epoch 126/300
# 804/804 [==============================] - 1s 651us/step - loss: 0.1771 - accuracy: 0.7446
# Epoch 127/300
# 804/804 [==============================] - 1s 647us/step - loss: 0.1771 - accuracy: 0.7445
# Epoch 128/300
# 804/804 [==============================] - 1s 646us/step - loss: 0.1771 - accuracy: 0.7446
# Epoch 129/300
# 804/804 [==============================] - 1s 655us/step - loss: 0.1771 - accuracy: 0.7446
# Epoch 130/300
# 804/804 [==============================] - 1s 653us/step - loss: 0.1771 - accuracy: 0.7446
# Epoch 131/300
# 804/804 [==============================] - 1s 643us/step - loss: 0.1771 - accuracy: 0.7446
# Epoch 132/300
# 804/804 [==============================] - 1s 655us/step - loss: 0.1771 - accuracy: 0.7444
# Epoch 133/300
# 804/804 [==============================] - 1s 646us/step - loss: 0.1771 - accuracy: 0.7446
# Epoch 134/300
# 804/804 [==============================] - 1s 649us/step - loss: 0.1771 - accuracy: 0.7445
# Epoch 135/300
# 804/804 [==============================] - 1s 644us/step - loss: 0.1771 - accuracy: 0.7445
# Epoch 136/300
# 804/804 [==============================] - 1s 648us/step - loss: 0.1771 - accuracy: 0.7446
# Epoch 137/300
# 804/804 [==============================] - 1s 643us/step - loss: 0.1771 - accuracy: 0.7444
# Epoch 138/300
# 804/804 [==============================] - 1s 660us/step - loss: 0.1771 - accuracy: 0.7444
# Epoch 139/300
# 804/804 [==============================] - 1s 641us/step - loss: 0.1771 - accuracy: 0.7444
# Epoch 140/300
# 804/804 [==============================] - 1s 651us/step - loss: 0.1771 - accuracy: 0.7445
# Epoch 141/300
# 804/804 [==============================] - 1s 646us/step - loss: 0.1771 - accuracy: 0.7446
# Epoch 142/300
# 804/804 [==============================] - 1s 655us/step - loss: 0.1771 - accuracy: 0.7446
# Epoch 143/300
# 804/804 [==============================] - 1s 647us/step - loss: 0.1771 - accuracy: 0.7445
# Epoch 144/300
# 804/804 [==============================] - 1s 659us/step - loss: 0.1771 - accuracy: 0.7446
# Epoch 145/300
# 804/804 [==============================] - 1s 641us/step - loss: 0.1771 - accuracy: 0.7445
# Epoch 146/300
# 804/804 [==============================] - 1s 648us/step - loss: 0.1771 - accuracy: 0.7446
# Epoch 147/300
# 804/804 [==============================] - 1s 640us/step - loss: 0.1771 - accuracy: 0.7446
# Epoch 148/300
# 804/804 [==============================] - 1s 647us/step - loss: 0.1771 - accuracy: 0.7446
# Epoch 149/300
# 804/804 [==============================] - 1s 647us/step - loss: 0.1771 - accuracy: 0.7446
# Epoch 150/300
# 804/804 [==============================] - 1s 643us/step - loss: 0.1771 - accuracy: 0.7446
# Epoch 151/300
# 804/804 [==============================] - 1s 652us/step - loss: 0.1771 - accuracy: 0.7446
# Epoch 152/300
# 804/804 [==============================] - 1s 646us/step - loss: 0.1771 - accuracy: 0.7445
# Epoch 153/300
# 804/804 [==============================] - 1s 650us/step - loss: 0.1771 - accuracy: 0.7446
# Epoch 154/300
# 804/804 [==============================] - 1s 645us/step - loss: 0.1771 - accuracy: 0.7444
# Epoch 155/300
# 804/804 [==============================] - 1s 646us/step - loss: 0.1771 - accuracy: 0.7446
# Epoch 156/300
# 804/804 [==============================] - 1s 651us/step - loss: 0.1771 - accuracy: 0.7446
# Epoch 157/300
# 804/804 [==============================] - 1s 648us/step - loss: 0.1771 - accuracy: 0.7446
# Epoch 158/300
# 804/804 [==============================] - 1s 642us/step - loss: 0.1771 - accuracy: 0.7446
# Epoch 159/300
# 804/804 [==============================] - 1s 655us/step - loss: 0.1771 - accuracy: 0.7444
# Epoch 160/300
# 804/804 [==============================] - 1s 652us/step - loss: 0.1770 - accuracy: 0.7446
# Epoch 161/300
# 804/804 [==============================] - 1s 650us/step - loss: 0.1770 - accuracy: 0.7446
# Epoch 162/300
# 804/804 [==============================] - 1s 645us/step - loss: 0.1770 - accuracy: 0.7445
# Epoch 163/300
# 804/804 [==============================] - 1s 648us/step - loss: 0.1770 - accuracy: 0.7446
# Epoch 164/300
# 804/804 [==============================] - 1s 650us/step - loss: 0.1770 - accuracy: 0.7446
# Epoch 165/300
# 804/804 [==============================] - 1s 650us/step - loss: 0.1770 - accuracy: 0.7446
# Epoch 166/300
# 804/804 [==============================] - 1s 641us/step - loss: 0.1770 - accuracy: 0.7446
# Epoch 167/300
# 804/804 [==============================] - 1s 646us/step - loss: 0.1770 - accuracy: 0.7446
# Epoch 168/300
# 804/804 [==============================] - 1s 652us/step - loss: 0.1770 - accuracy: 0.7446
# Epoch 169/300
# 804/804 [==============================] - 1s 673us/step - loss: 0.1770 - accuracy: 0.7446
# Epoch 170/300
# 804/804 [==============================] - 1s 645us/step - loss: 0.1770 - accuracy: 0.7445
# Epoch 171/300
# 804/804 [==============================] - 1s 652us/step - loss: 0.1770 - accuracy: 0.7446
# Epoch 172/300
# 804/804 [==============================] - 1s 645us/step - loss: 0.1770 - accuracy: 0.7446
# Epoch 173/300
# 804/804 [==============================] - 1s 651us/step - loss: 0.1770 - accuracy: 0.7446
# Epoch 174/300
# 804/804 [==============================] - 1s 645us/step - loss: 0.1770 - accuracy: 0.7445
# Epoch 175/300
# 804/804 [==============================] - 1s 656us/step - loss: 0.1770 - accuracy: 0.7446
# Epoch 176/300
# 804/804 [==============================] - 1s 647us/step - loss: 0.1770 - accuracy: 0.7445
# Epoch 177/300
# 804/804 [==============================] - 1s 653us/step - loss: 0.1770 - accuracy: 0.7445
# Epoch 178/300
# 804/804 [==============================] - 1s 642us/step - loss: 0.1770 - accuracy: 0.7445
# Epoch 179/300
# 804/804 [==============================] - 1s 657us/step - loss: 0.1770 - accuracy: 0.7445
# Epoch 180/300
# 804/804 [==============================] - 1s 645us/step - loss: 0.1770 - accuracy: 0.7446
# Epoch 181/300
# 804/804 [==============================] - 1s 649us/step - loss: 0.1770 - accuracy: 0.7446
# Epoch 182/300
# 804/804 [==============================] - 1s 646us/step - loss: 0.1770 - accuracy: 0.7446
# Epoch 183/300
# 804/804 [==============================] - 1s 649us/step - loss: 0.1770 - accuracy: 0.7445
# Epoch 184/300
# 804/804 [==============================] - 1s 652us/step - loss: 0.1770 - accuracy: 0.7446
# Epoch 185/300
# 804/804 [==============================] - 1s 642us/step - loss: 0.1770 - accuracy: 0.7446
# Epoch 186/300
# 804/804 [==============================] - 1s 649us/step - loss: 0.1770 - accuracy: 0.7446
# Epoch 187/300
# 804/804 [==============================] - 1s 648us/step - loss: 0.1770 - accuracy: 0.7446
# Epoch 188/300
# 804/804 [==============================] - 1s 650us/step - loss: 0.1770 - accuracy: 0.7446
# Epoch 189/300
# 804/804 [==============================] - 1s 645us/step - loss: 0.1770 - accuracy: 0.7444
# Epoch 190/300
# 804/804 [==============================] - 1s 650us/step - loss: 0.1770 - accuracy: 0.7446
# Epoch 191/300
# 804/804 [==============================] - 1s 647us/step - loss: 0.1770 - accuracy: 0.7446
# Epoch 192/300
# 804/804 [==============================] - 1s 648us/step - loss: 0.1770 - accuracy: 0.7445
# Epoch 193/300
# 804/804 [==============================] - 1s 641us/step - loss: 0.1770 - accuracy: 0.7446
# Epoch 194/300
# 804/804 [==============================] - 1s 650us/step - loss: 0.1770 - accuracy: 0.7446
# Epoch 195/300
# 804/804 [==============================] - 1s 643us/step - loss: 0.1770 - accuracy: 0.7446
# Epoch 196/300
# 804/804 [==============================] - 1s 651us/step - loss: 0.1770 - accuracy: 0.7446
# Epoch 197/300
# 804/804 [==============================] - 1s 644us/step - loss: 0.1770 - accuracy: 0.7446
# Epoch 198/300
# 804/804 [==============================] - 1s 654us/step - loss: 0.1770 - accuracy: 0.7446
# Epoch 199/300
# 804/804 [==============================] - 1s 642us/step - loss: 0.1770 - accuracy: 0.7446
# Epoch 200/300
# 804/804 [==============================] - 1s 647us/step - loss: 0.1770 - accuracy: 0.7446
# Epoch 201/300
# 804/804 [==============================] - 1s 643us/step - loss: 0.1770 - accuracy: 0.7445
# Epoch 202/300
# 804/804 [==============================] - 1s 658us/step - loss: 0.1770 - accuracy: 0.7445
# Epoch 203/300
# 804/804 [==============================] - 1s 648us/step - loss: 0.1770 - accuracy: 0.7446
# Epoch 204/300
# 804/804 [==============================] - 1s 657us/step - loss: 0.1770 - accuracy: 0.7446
# Epoch 205/300
# 804/804 [==============================] - 1s 650us/step - loss: 0.1770 - accuracy: 0.7446
# Epoch 206/300
# 804/804 [==============================] - 1s 648us/step - loss: 0.1770 - accuracy: 0.7445
# Epoch 207/300
# 804/804 [==============================] - 1s 645us/step - loss: 0.1770 - accuracy: 0.7446
# Epoch 208/300
# 804/804 [==============================] - 1s 651us/step - loss: 0.1770 - accuracy: 0.7446
# Epoch 209/300
# 804/804 [==============================] - 1s 649us/step - loss: 0.1770 - accuracy: 0.7446
# Epoch 210/300
# 804/804 [==============================] - 1s 646us/step - loss: 0.1770 - accuracy: 0.7445
# Epoch 211/300
# 804/804 [==============================] - 1s 640us/step - loss: 0.1770 - accuracy: 0.7446
# Epoch 212/300
# 804/804 [==============================] - 1s 649us/step - loss: 0.1770 - accuracy: 0.7446
# Epoch 213/300
# 804/804 [==============================] - 1s 646us/step - loss: 0.1770 - accuracy: 0.7445
# Epoch 214/300
# 804/804 [==============================] - 1s 641us/step - loss: 0.1770 - accuracy: 0.7446
# Epoch 215/300
# 804/804 [==============================] - 1s 646us/step - loss: 0.1770 - accuracy: 0.7445
# Epoch 216/300
# 804/804 [==============================] - 1s 645us/step - loss: 0.1770 - accuracy: 0.7445
# Epoch 217/300
# 804/804 [==============================] - 1s 645us/step - loss: 0.1770 - accuracy: 0.7444
# Epoch 218/300
# 804/804 [==============================] - 1s 643us/step - loss: 0.1770 - accuracy: 0.7446
# Epoch 219/300
# 804/804 [==============================] - 1s 659us/step - loss: 0.1770 - accuracy: 0.7446
# Epoch 220/300
# 804/804 [==============================] - 1s 640us/step - loss: 0.1770 - accuracy: 0.7446
# Epoch 221/300
# 804/804 [==============================] - 1s 651us/step - loss: 0.1770 - accuracy: 0.7445
# Epoch 222/300
# 804/804 [==============================] - 1s 646us/step - loss: 0.1770 - accuracy: 0.7446
# Epoch 223/300
# 804/804 [==============================] - 1s 661us/step - loss: 0.1770 - accuracy: 0.7447
# Epoch 224/300
# 804/804 [==============================] - 1s 638us/step - loss: 0.1770 - accuracy: 0.7445
# Epoch 225/300
# 804/804 [==============================] - 1s 641us/step - loss: 0.1770 - accuracy: 0.7445
# Epoch 226/300
# 804/804 [==============================] - 1s 647us/step - loss: 0.1770 - accuracy: 0.7445
# Epoch 227/300
# 804/804 [==============================] - 1s 648us/step - loss: 0.1770 - accuracy: 0.7445
# Epoch 228/300
# 804/804 [==============================] - 1s 640us/step - loss: 0.1770 - accuracy: 0.7446
# Epoch 229/300
# 804/804 [==============================] - 1s 646us/step - loss: 0.1770 - accuracy: 0.7446
# Epoch 230/300
# 804/804 [==============================] - 1s 651us/step - loss: 0.1770 - accuracy: 0.7446
# Epoch 231/300
# 804/804 [==============================] - 1s 646us/step - loss: 0.1770 - accuracy: 0.7445
# Epoch 232/300
# 804/804 [==============================] - 1s 638us/step - loss: 0.1770 - accuracy: 0.7445
# Epoch 233/300
# 804/804 [==============================] - 1s 644us/step - loss: 0.1770 - accuracy: 0.7446
# Epoch 234/300
# 804/804 [==============================] - 1s 657us/step - loss: 0.1770 - accuracy: 0.7446
# Epoch 235/300
# 804/804 [==============================] - 1s 646us/step - loss: 0.1770 - accuracy: 0.7446
# Epoch 236/300
# 804/804 [==============================] - 1s 645us/step - loss: 0.1770 - accuracy: 0.7446
# Epoch 237/300
# 804/804 [==============================] - 1s 655us/step - loss: 0.1770 - accuracy: 0.7446
# Epoch 238/300
# 804/804 [==============================] - 1s 640us/step - loss: 0.1770 - accuracy: 0.7445
# Epoch 239/300
# 804/804 [==============================] - 1s 648us/step - loss: 0.1770 - accuracy: 0.7446
# Epoch 240/300
# 804/804 [==============================] - 1s 646us/step - loss: 0.1770 - accuracy: 0.7446
# Epoch 241/300
# 804/804 [==============================] - 1s 643us/step - loss: 0.1770 - accuracy: 0.7447
# Epoch 242/300
# 804/804 [==============================] - 1s 643us/step - loss: 0.1770 - accuracy: 0.7445
# Epoch 243/300
# 804/804 [==============================] - 1s 642us/step - loss: 0.1770 - accuracy: 0.7446
# Epoch 244/300
# 804/804 [==============================] - 1s 659us/step - loss: 0.1770 - accuracy: 0.7446
# Epoch 245/300
# 804/804 [==============================] - 1s 638us/step - loss: 0.1770 - accuracy: 0.7446
# Epoch 246/300
# 804/804 [==============================] - 1s 645us/step - loss: 0.1770 - accuracy: 0.7446
# Epoch 247/300
# 804/804 [==============================] - 1s 652us/step - loss: 0.1770 - accuracy: 0.7445
# Epoch 248/300
# 804/804 [==============================] - 1s 648us/step - loss: 0.1770 - accuracy: 0.7446
# Epoch 249/300
# 804/804 [==============================] - 1s 639us/step - loss: 0.1770 - accuracy: 0.7445
# Epoch 250/300
# 804/804 [==============================] - 1s 652us/step - loss: 0.1770 - accuracy: 0.7445
# Epoch 251/300
# 804/804 [==============================] - 1s 638us/step - loss: 0.1770 - accuracy: 0.7446
# Epoch 252/300
# 804/804 [==============================] - 1s 644us/step - loss: 0.1770 - accuracy: 0.7445
# Epoch 253/300
# 804/804 [==============================] - 1s 642us/step - loss: 0.1770 - accuracy: 0.7446
# Epoch 254/300
# 804/804 [==============================] - 1s 654us/step - loss: 0.1770 - accuracy: 0.7445
# Epoch 255/300
# 804/804 [==============================] - 1s 642us/step - loss: 0.1770 - accuracy: 0.7446
# Epoch 256/300
# 804/804 [==============================] - 1s 647us/step - loss: 0.1770 - accuracy: 0.7446
# Epoch 257/300
# 804/804 [==============================] - 1s 643us/step - loss: 0.1770 - accuracy: 0.7445
# Epoch 258/300
# 804/804 [==============================] - 1s 647us/step - loss: 0.1770 - accuracy: 0.7446
# Epoch 259/300
# 804/804 [==============================] - 1s 643us/step - loss: 0.1770 - accuracy: 0.7446
# Epoch 260/300
# 804/804 [==============================] - 1s 656us/step - loss: 0.1770 - accuracy: 0.7446
# Epoch 261/300
# 804/804 [==============================] - 1s 642us/step - loss: 0.1770 - accuracy: 0.7446
# Epoch 262/300
# 804/804 [==============================] - 1s 645us/step - loss: 0.1770 - accuracy: 0.7446
# Epoch 263/300
# 804/804 [==============================] - 1s 640us/step - loss: 0.1770 - accuracy: 0.7446
# Epoch 264/300
# 804/804 [==============================] - 1s 652us/step - loss: 0.1770 - accuracy: 0.7446
# Epoch 265/300
# 804/804 [==============================] - 1s 641us/step - loss: 0.1770 - accuracy: 0.7446
# Epoch 266/300
# 804/804 [==============================] - 1s 648us/step - loss: 0.1770 - accuracy: 0.7446
# Epoch 267/300
# 804/804 [==============================] - 1s 646us/step - loss: 0.1770 - accuracy: 0.7445
# Epoch 268/300
# 804/804 [==============================] - 1s 647us/step - loss: 0.1770 - accuracy: 0.7446
# Epoch 269/300
# 804/804 [==============================] - 1s 641us/step - loss: 0.1770 - accuracy: 0.7446
# Epoch 270/300
# 804/804 [==============================] - 1s 648us/step - loss: 0.1770 - accuracy: 0.7446
# Epoch 271/300
# 804/804 [==============================] - 1s 656us/step - loss: 0.1770 - accuracy: 0.7446
# Epoch 272/300
# 804/804 [==============================] - 1s 642us/step - loss: 0.1770 - accuracy: 0.7446
# Epoch 273/300
# 804/804 [==============================] - 1s 643us/step - loss: 0.1770 - accuracy: 0.7446
# Epoch 274/300
# 804/804 [==============================] - 1s 650us/step - loss: 0.1770 - accuracy: 0.7446
# Epoch 275/300
# 804/804 [==============================] - 1s 648us/step - loss: 0.1770 - accuracy: 0.7446
# Epoch 276/300
# 804/804 [==============================] - 1s 640us/step - loss: 0.1770 - accuracy: 0.7446
# Epoch 277/300
# 804/804 [==============================] - 1s 653us/step - loss: 0.1770 - accuracy: 0.7446
# Epoch 278/300
# 804/804 [==============================] - 1s 642us/step - loss: 0.1770 - accuracy: 0.7447
# Epoch 279/300
# 804/804 [==============================] - 1s 649us/step - loss: 0.1770 - accuracy: 0.7446
# Epoch 280/300
# 804/804 [==============================] - 1s 650us/step - loss: 0.1770 - accuracy: 0.7445
# Epoch 281/300
# 804/804 [==============================] - 1s 647us/step - loss: 0.1770 - accuracy: 0.7446
# Epoch 282/300
# 804/804 [==============================] - 1s 642us/step - loss: 0.1770 - accuracy: 0.7445
# Epoch 283/300
# 804/804 [==============================] - 1s 657us/step - loss: 0.1770 - accuracy: 0.7445
# Epoch 284/300
# 804/804 [==============================] - 1s 661us/step - loss: 0.1770 - accuracy: 0.7445
# Epoch 285/300
# 804/804 [==============================] - 1s 648us/step - loss: 0.1770 - accuracy: 0.7446
# Epoch 286/300
# 804/804 [==============================] - 1s 653us/step - loss: 0.1770 - accuracy: 0.7446
# Epoch 287/300
# 804/804 [==============================] - 1s 646us/step - loss: 0.1770 - accuracy: 0.7446
# Epoch 288/300
# 804/804 [==============================] - 1s 641us/step - loss: 0.1770 - accuracy: 0.7446
# Epoch 289/300
# 804/804 [==============================] - 1s 653us/step - loss: 0.1770 - accuracy: 0.7446
# Epoch 290/300
# 804/804 [==============================] - 1s 645us/step - loss: 0.1770 - accuracy: 0.7445
# Epoch 291/300
# 804/804 [==============================] - 1s 646us/step - loss: 0.1770 - accuracy: 0.7446
# Epoch 292/300
# 804/804 [==============================] - 1s 650us/step - loss: 0.1770 - accuracy: 0.7446
# Epoch 293/300
# 804/804 [==============================] - 1s 648us/step - loss: 0.1770 - accuracy: 0.7446
# Epoch 294/300
# 804/804 [==============================] - 1s 642us/step - loss: 0.1770 - accuracy: 0.7445
# Epoch 295/300
# 804/804 [==============================] - 1s 645us/step - loss: 0.1770 - accuracy: 0.7445
# Epoch 296/300
# 804/804 [==============================] - 1s 654us/step - loss: 0.1770 - accuracy: 0.7446
# Epoch 297/300
# 804/804 [==============================] - 1s 652us/step - loss: 0.1770 - accuracy: 0.7446
# Epoch 298/300
# 804/804 [==============================] - 1s 645us/step - loss: 0.1770 - accuracy: 0.7446
# Epoch 299/300
# 804/804 [==============================] - 1s 653us/step - loss: 0.1770 - accuracy: 0.7446
# Epoch 300/300
# 804/804 [==============================] - 1s 642us/step - loss: 0.1770 - accuracy: 0.7447

# %%
# Evaluate the model using the test data
model_loss, model_accuracy = nn.evaluate(X_test_scaled, y_test, verbose=2)
print(f"Loss: {model_loss}, Accuracy: {model_accuracy}")
# Out:
# 268/268 - 0s - loss: 0.1877 - accuracy: 0.7252 - 159ms/epoch - 592us/step
# Loss: 0.18769849836826324, Accuracy: 0.7252478003501892

# %%
# Export our model to HDF5 file
nn.save("./Outputs/charity_model.h5")
print("Model saved to Outputs folder.")
# Out:
# Model saved to Outputs folder.
